# %% [markdown]
# # LangChain Deep Technical Blog - Implementation

# %%
# !pip install langchain transformers torch -q

# %%
from transformers import pipeline
from langchain.llms import HuggingFacePipeline

pipe = pipeline("text-generation", model="distilgpt2")
llm = HuggingFacePipeline(pipeline=pipe)

# %%
response = llm.invoke("Explain Artificial Intelligence in simple terms")
print(response)

# %%
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain

prompt = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple terms"
)

chain = LLMChain(llm=llm, prompt=prompt)
result = chain.invoke({"topic": "LangChain"})
print(result["text"])

# %%
from langchain.memory import ConversationBufferMemory
from langchain.chains import ConversationChain

memory = ConversationBufferMemory()

chat = ConversationChain(llm=llm, memory=memory)

print(chat.predict(input="My name is Alex"))
print(chat.predict(input="What is my name?"))

# %%
def calculator(expression):
    return eval(expression)

print("Answer:", calculator("10 * 5"))
